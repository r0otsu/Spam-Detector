# %%
import numpy as np
import pandas as pd
import nltk
nltk.download('punkt_tab')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import ngrams
import re
#Visualization
import matplotlib.pyplot as plt
from collections import Counter
from wordcloud import WordCloud

#Feature Engineering
import string
import re
from keras._tf_keras.keras.preprocessing.text import Tokenizer
from keras._tf_keras.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

#Machine Learning Model
from sklearn.model_selection import train_test_split
from keras._tf_keras.keras.models import Sequential
from keras._tf_keras.keras.layers import Dense,LSTM,Embedding,Dropout,Activation,Bidirectional
import tensorflow as tf

#Evaluation Metric
from sklearn.metrics import confusion_matrix,f1_score, precision_score,recall_score
import seaborn as sns
import pickle
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\liyuanyuan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
df=pd.read_csv("email_text.csv")
df.head(5)
# Out:
#    label                                               text
# 0      1  do you feel the pressure to perform and not ri...
# 1      0  hi i've just updated from the gulus and i chec...
# 2      1  mega authenticv i a g r a discount pricec i a ...
# 3      1  hey billy it was really fun going out the othe...
# 4      1  system of the home it will have the capabiliti...

# %%
print(df.isnull().sum())
# Out:
# label    0
# text     0
# dtype: int64

# %%
df.shape
# Out:
# (53668, 2)

# %%
df['text'] = df['text'].str.lower()

# %%
def remove_special_characters(word):
    return word.translate(str.maketrans('', '', string.punctuation))
df['text'] = df['text'].apply(remove_special_characters)

# %%
ENGLISH_STOP_WORDS = set(stopwords.words('english'))

def remove_stop_words(words):
    return [word for word in words if word not in ENGLISH_STOP_WORDS]

#Tokenize the text
df['text'] = df['text'].apply(word_tokenize)

#Remove stop words
df['text'] = df['text'].apply(remove_stop_words)

#Rejoin words for EDA
df['text'] = df['text'].apply(' '.join)

# %%
def remove_hyperlink(word):
    return re.sub(r"http\S+", "", word)

df['text'] = df['text'].apply(remove_hyperlink)

# %%
for i in range (1,5):
    print("Email #"+str(i))
    spam_email = df[df['label'] == 1]['text'].iloc[i]
    print(spam_email+"\n")
# Out:
# Email #1
# mega authenticv g r discount pricec l discount pricedo miss click http www moujsjkhchum com
#
# Email #2
# hey billy really fun going night talking said felt insecure manhood noticed toilets quite small area worry website telling secret weapon extra escapenumber inches trust girls love bigger ones ive escapenumber times many chicks since used pills year ago package used escapenumber month supply one worth every cent website http ctmay com ring weekend go drink let know secrets later dude brad
#
# Email #3
# system home capabilities linked far know within part respect affects technology society science ad agencies cashin g commerciality photographs paint electronic canvases still seems like silence white black lights didnt happen although far p erfect especially precludes vast explanation understand people rely avant gardes art world additionally writers lawyers yet ach full potential imagine future computer screen ho w would perception artificial image business apart computerized sign shops filtered unnecessary laborers technology comp anies monopoly service services roots tre nd western culture since dark ages possibilities unimag inative human thinking friendly industry isnt welcoming new people thoughts c entered computer voice activation capabilities mo pervasive years go email system organizatio n individual booths designer architects draftspeople condition call hyper awareness anything everything five always took prid e knowing reason hired able conduct daily work activities without leaving hydro bill spend time v r potatoes taking granted convenience technology newer model computer decided investigate little condition call hyper awareness thing everything five sports leisure activities factor motivating king communication info networks like technological take ove r conversely new occupations may result computer either im bei ng demanding dont process guide book chart could therefor charging much lower price n ever realized virtual reality already sharp technology pass well oh well places making yet another barrier people much like formal structure speel would make acceptable drawings th e work computer creation
#
# Email #4
# program creative abilities artist monitoring economic structuring transformed social space ca n absolutely space amounts information subject see homes dimension worldly consciousness quantum mechanics busy vr used al ong lines society benefit fewer use economic restructuring transformed social feared right first moved came eliminating need paper medium communication breakthrough w ill definitely impact studies time fa miliar computers home sits couch night saying intimidation get case opted computerizat ion integrating stage systems interior design st udent noted computer programs taking jobs many people work force course governed p c well controlling day day concerns could therefor charging much lower price blood allowing body society function smoothly idea general purpose simulation went explain point people never leave terminal manipulation digital production visual artwork provides ancient artifacts computer kept permanent global village arts g roundwork culture technology open whole new world communication th e answer alive painting drawing fact sculptor friend mine finish oh ever outline maybe simply cutter cut letters self adhesive vinyl artificial naturally see stages development chooses live smooth transition positive vibe caring virtual reality treated suc h unique modern concept interior design student noted computer programs amount people becoming part new community purchase convent ional means receive computer designing logos layou ts signs done fashion statement advertising ploy moral issue ever reas chooses keep advancing technical age group th e advancing technology affects th

# %%
for i in range (1,5):
    print("Email #"+str(i))
    legitimate_email = df[df['label'] == 0]['text'].iloc[i]
    print(legitimate_email+"\n")
# Out:
# Email #1
# hi use r find escapenumber confidence interval sensitivity specificity following diagnostic test particular diagnostic test multiple sclerosis conducted escapenumber ms patients escapenumber healthy subjects escapenumber ms patients classified healthy escapenumber healthy subjects classified suffering ms furthermore need find number ms patients required sensitivity escapenumber simple r command completely new r help please jochen view message context http www nabble com confidence intervals help tfescapenumber html aescapenumber sent r help mailing list archive nabble com r help stat math ethz ch mailing list  stat ethz ch mailman listinfo r help please read posting guide http www r project org posting guide html provide commented minimal self contained reproducible code
#
# Email #2
# hm sounds like homework problem maybe start figuring without r whats approach would calculate search r help possible key words came sarah escapenumber escapenumber escapenumber jochen f wrote hi use r find escapenumber confidence interval sensitivity specificity following diagnostic test particular diagnostic test multiple sclerosis conducted escapenumber ms patients escapenumber healthy subjects escapenumber ms patients classified healthy escapenumber healthy subjects classified suffering ms furthermore need find number ms patients required sensitivity escapenumber simple r command completely new r help please jochen sarah goslee http www functionaldiversity org r help stat math ethz ch mailing list  stat ethz ch mailman listinfo r help please read posting guide http www r project org posting guide html provide commented minimal self contained reproducible code
#
# Email #3
# gruesse v harishankar schrieb escapenumber escapenumber escapenumber escapenumber escapenumber problem hp compaq nxescapenumber laptop since upgrading kernel escapenumber escapenumber escapenumber escapenumber escapenumber currently running version escapenumber escapenumber escapenumber dfsg escapenumber escapenumber debian etch ive unable get acpi work machine result dont get battery ac status machine doesnt power properly shut already seen http www debian org releases stable iescapenumber release notes ch information en html hp acpi regards hari gruß gerhard kernel panic could determine whether bit one zero sqrt escapenumber pi j k u g unsubscribe email debian laptop request lists debian org subject unsubscribe trouble contact listmaster lists debian org
#
# Email #4
# daer r helpers anyone help following get mcmcsamp txt lmerescapenumberf markov chain monte carlo mcmc output start escapenumber end escapenumber thinning interval escapenumber mcsamp txt lmerescapenumberf error bugs array sims program lmer n iter n iter n burnin n burnin error parameter sigma parameters save attached arm package library arm loading required package escapelong arm version escapenumber escapenumber escapenumber built escapenumber escapenumber escapenumber working directory users mk documents projects mike prediss exp text loading required package foreign sessioninfo r version escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber iescapenumber apple darwinescapenumber escapenumber escapenumber locale c attached base packages escapenumber tools grid datasets stats graphics grdevices utils methods escapenumber base attached packages foreign arm escapelong coda hmisc gmodels effects lmeescapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber matrix car weaver codetools digest xtable latticeextra lattice escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber gridbase mass jgr iplots javagd rjava escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber escapenumber thanks mk professor michael kubovy university virginia department psychology usps p box escapenumber charlottesville va escapenumber escapenumber parcels room escapenumber gilmer hall mccormick road charlottesville va escapenumber office bescapenumber escapenumber escapenumber escapenumber escapenumber lab bescapenumber escapenumber escapenumber escapenumber escapenumber fax escapenumber escapenumber escapenumber escapenumber www http www people virginia edu mkescapenumbery r help stat math ethz ch mailing list  stat ethz ch mailman listinfo r help please read posting guide http www r project org posting guide html provide commented minimal self contained reproducible code

# %%
# Count the number of spam and legitimate emails
email_counts = df['label'].value_counts()

# Plotting
plt.figure(figsize=(8, 6))
plt.pie(email_counts, labels=['Spam (1)', 'Legitimate (0)'], autopct='%1.1f%%', startangle=140, colors=['tomato', 'lightblue'])
plt.title('Comparison of Spam and Legitimate Emails')
plt.show()

# %%
# Separate the spam and legitimate emails
spam_emails = df[df['label'] == 1]['text']
legit_emails = df[df['label'] == 0]['text']

# Count word frequencies for spam
spam_words = Counter()
spam_emails.apply(lambda x: spam_words.update(x.split()))

# Count word frequencies for legitimate emails
legit_words = Counter()
legit_emails.apply(lambda x: legit_words.update(x.split()))

# Get the most common words in spam and legitimate emails
spam_common = spam_words.most_common(10)
legit_common = legit_words.most_common(10)

# Convert to DataFrame
spam_common_df = pd.DataFrame(spam_common, columns=['Word', 'Frequency'])
legit_common_df = pd.DataFrame(legit_common, columns=['Word', 'Frequency'])

# %%
# Plotting the most common words in spam emails
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.bar(spam_common_df['Word'], spam_common_df['Frequency'], color='red')
plt.title('Most Common Words in Spam Emails')
plt.xticks(rotation=45)

# Plotting the most common words in legitimate emails
plt.subplot(1, 2, 2)
plt.bar(legit_common_df['Word'], legit_common_df['Frequency'], color='green')
plt.title('Most Common Words in Legitimate Emails')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# Generate a word cloud image for spam words
spam_wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(spam_emails))

# Display the image
plt.figure(figsize=(10, 5))
plt.imshow(spam_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Extract n-grams from text
def generate_ngrams(text, n=2):
    # Split the text into words
    words = text.split()
    # Ensure that there is no enough words
    if len(words) >= n:
        return [' '.join(grams) for grams in ngrams(words, n)]
    else:
        return []

# Convert bigrams
df['bigrams'] = df['text'].apply(lambda x: generate_ngrams(x, n=2))

# count the frequencies
bigram_counts = Counter([bigram for sublist in df['bigrams'] for bigram in sublist])

# Get the most common bigrams
most_common_bigrams = bigram_counts.most_common(10)

# Convert to DataFrame for visualization
bigrams_df = pd.DataFrame(most_common_bigrams, columns=['Bigram', 'Frequency'])

# Plot the most common bigrams
plt.figure(figsize=(10, 5))
plt.barh(bigrams_df['Bigram'], bigrams_df['Frequency'], color='skyblue')
plt.xlabel('Frequency')
plt.title('Top 10 Most Common Bigrams')
plt.gca().invert_yaxis()  # Display the highest count at the top
plt.show()

# %%
# Split the data into features and target
X = df['text']  
y = df['label']
print(X)

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

max_features = 5000 
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(X_train)

with open('tokenizer.pkl', 'wb') as f:
    pickle.dump(tokenizer, f)

# Convert texts to sequences
X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)
#Average Length
average_length = df['text'].apply(len).mean()
print("Average Length: "+str(average_length))
max_length = 500 #Set to average length

# Padding sequences
X_train_padded = pad_sequences(X_train_seq, maxlen=max_length, padding='post')
X_test_padded = pad_sequences(X_test_seq, maxlen=max_length, padding='post')
print(X_test_padded)

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)
# Out:
# 0        feel pressure perform rising occasion try v ia...
# 1        hi ive updated gulus check mirrors seems littl...
# 2        mega authenticv g r discount pricec l discount...
# 3        hey billy really fun going night talking said ...
# 4        system home capabilities linked far know withi...
#                                ...
# 53663    versuchen sie unser produkt und sie werden fuh...
# 53664    may high expectations associates also give hig...
# 53665    interested cook little tcltkhelp function ease...
# 53666    hello wrote call sqlfetch channel studie funct...
# 53667    well implicated stage seen minute began termin...
# Name: text, Length: 53668, dtype: object
# Average Length: 1465.8951516732504
# [[1332  142  376 ...    0    0    0]
#  [ 573    1  314 ...    0    0    0]
#  [  28  210   81 ...    0    0    0]
#  ...
#  [ 246 1243 1020 ...    0    0    0]
#  [2390   54   36 ...    0    0    0]
#  [ 798  227 1487 ...    0    0    0]]

# %%
embedding_vector_length = 32
model = tf.keras.Sequential()
model.add(Embedding(max_features, embedding_vector_length))
model.add(Bidirectional(tf.keras.layers.LSTM(64)))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.build(input_shape=(None, 500))
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 500, 32)             │         160,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 128)                 │          49,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 16)                  │           2,064 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 211,745 (827.13 KB)
#  Trainable params: 211,745 (827.13 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
history = model.fit(X_train_padded, y_train_encoded, 
                    batch_size=512, 
                    epochs=10, 
                    validation_data=(X_test_padded, y_test_encoded))
model.save('LSTM.h5')
# Out:
# Epoch 1/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 242s 3s/step - accuracy: 0.7355 - loss: 0.4810 - val_accuracy: 0.9734 - val_loss: 0.0907
# Epoch 2/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 325s 4s/step - accuracy: 0.9800 - loss: 0.0782 - val_accuracy: 0.9855 - val_loss: 0.0553
# Epoch 3/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 376s 5s/step - accuracy: 0.9877 - loss: 0.0468 - val_accuracy: 0.9877 - val_loss: 0.0469
# Epoch 4/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 353s 5s/step - accuracy: 0.9923 - loss: 0.0340 - val_accuracy: 0.9893 - val_loss: 0.0438
# Epoch 5/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 360s 5s/step - accuracy: 0.9940 - loss: 0.0281 - val_accuracy: 0.9895 - val_loss: 0.0446
# Epoch 6/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 367s 5s/step - accuracy: 0.9953 - loss: 0.0205 - val_accuracy: 0.9876 - val_loss: 0.0472
# Epoch 7/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 390s 5s/step - accuracy: 0.9956 - loss: 0.0203 - val_accuracy: 0.9892 - val_loss: 0.0523
# Epoch 8/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 385s 5s/step - accuracy: 0.9966 - loss: 0.0144 - val_accuracy: 0.9578 - val_loss: 0.1148
# Epoch 9/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 395s 5s/step - accuracy: 0.9800 - loss: 0.0584 - val_accuracy: 0.9879 - val_loss: 0.0486
# Epoch 10/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 399s 5s/step - accuracy: 0.9954 - loss: 0.0183 - val_accuracy: 0.9802 - val_loss: 0.0690
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
y_pred = model.predict(X_test_padded)
y_predict = [1 if o > 0.5 else 0 for o in y_pred]
print(y_pred)
# Out:
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step
# [[9.9878132e-01]
#  [7.0717355e-04]
#  [2.3761988e-04]
#  ...
#  [9.9602997e-01]
#  [1.0892027e-04]
#  [9.9985367e-01]]

# %%
cf_matrix =confusion_matrix(y_test_encoded,y_predict)
tn, fp, fn, tp = confusion_matrix(y_test_encoded,y_predict).ravel()
print("Precision: {:.2f}%".format(100 * precision_score(y_test_encoded, y_predict)))
print("Recall: {:.2f}%".format(100 * recall_score(y_test_encoded, y_predict)))
print("F1 Score: {:.2f}%".format(100 * f1_score(y_test_encoded,y_predict)))
# Out:
# Precision: 97.60%
# Recall: 98.95%
# F1 Score: 98.27%

# %%
ax= plt.subplot()
#annot=True to annotate cells
sns.heatmap(cf_matrix, annot=True, ax = ax,cmap='Blues',fmt='');
# labels, title and ticks
ax.set_xlabel('Predicted labels');
ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['Not Spam', 'Spam']); ax.yaxis.set_ticklabels(['Not Spam', 'Spam']);
